# %% [markdown]
# # Text Analytics

# %% [markdown]
# <h3>SPAM</h3>

# %% [markdown]
# <h4>Import Libraries</h4>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# <h4>Import the text dataset (spam)</h4>

# %%
spam = pd.read_csv('spam.txt', delimiter = '\t', quoting = 3, encoding = "ISO-8859-1") #    Ignoring " with quoting = 3
spam.head()
# Out:
#                                                 text
# 0  Free entry in 2 a wkly comp to win FA Cup fina...
# 1  "FreeMsg Hey there darling it's been 3 week's ...
# 2  WINNER!! As a valued network customer you have...
# 3  Had your mobile 11 months or more? U R entitle...
# 4  "SIX chances to win CASH! From 100 to 20,000 p...

# %%
spam.shape
# Out:
# (747, 1)

# %%
import re 
import nltk
#   nltk.download('all')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
corpus = []
for i in range(0, 747):
    feedback = re.sub('[^a-zA-Z]', ' ', spam['text'][i]) #   Keeping texts only
    feedback = feedback.lower() #   All Lowercase
    feedback = feedback.split() #   Creating list of review words
    ps = PorterStemmer()
    # Remove stopwords & Stemming (Keeping root word only )
    feedback = [ps.stem(word) for word in feedback if not word in set(stopwords.words('english'))]
    feedback = ' '.join(feedback)
    corpus.append(feedback)

# %%
print(corpus[0:15])
# Out:
# ['free entri wkli comp win fa cup final tkt st may text fa receiv entri question std txt rate c appli', 'freemsg hey darl week word back like fun still tb ok xxx std chg send rcv', 'winner valu network custom select receivea prize reward claim call claim code kl valid hour', 'mobil month u r entitl updat latest colour mobil camera free call mobil updat co free', 'six chanc win cash pound txt csh send cost p day day tsandc appli repli hl info', 'urgent week free membership prize jackpot txt word claim c www dbuk net lccltd pobox ldnw rw', 'xxxmobilemovieclub use credit click wap link next txt messag click http wap xxxmobilemovieclub com n qjkgighjjgcbl', 'england v macedonia dont miss goal team news txt ur nation team eg england tri wale scotland txt poboxox w wq', 'thank subscript rington uk mobil charg month pleas confirm repli ye repli charg', 'rodger burn msg tri call repli sm free nokia mobil free camcord pleas call deliveri tomorrow', 'sm ac sptv new jersey devil detroit red wing play ice hockey correct incorrect end repli end sptv', 'congrat year special cinema pass call c suprman v matrix starwar etc free bx ip pm dont miss', 'valu custom pleas advis follow recent review mob award bonu prize call', 'urgent ur award complimentari trip eurodisinc trav aco entri claim txt di morefrmmob shracomorsglsuplt ls aj', 'hear new divorc barbi come ken stuff']

# %%
#!pip install wordcloud
from wordcloud import WordCloud
corpus = str(corpus)
wordcloud = WordCloud(width=580, height=580, margin=0).generate(corpus)

# Display the generated image:
#plt.figure(figsize=[25,15])
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# <h3>Word Count</h3>

# %%
import os
import nltk
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
corpus = PlaintextCorpusReader(os.getcwd(),"spam.txt", encoding = "ISO-8859-1" )
sentences = corpus.sents() 
print(sentences)
# Out:
# [['text', 'Free', 'entry', 'in', '2', 'a', 'wkly', 'comp', 'to', 'win', 'FA', 'Cup', 'final', 'tkts', '21st', 'May', '2005', '.'], ['Text', 'FA', 'to', '87121', 'to', 'receive', 'entry', 'question', '(', 'std', 'txt', 'rate', ')', 'T', '&', 'C', "'", 's', 'apply', '08452810075over18', "'", 's', '"', 'FreeMsg', 'Hey', 'there', 'darling', 'it', "'", 's', 'been', '3', 'week', "'", 's', 'now', 'and', 'no', 'word', 'back', '!'], ...]

# %% [markdown]
# <h3>Import and Tokenize</h3>

# %%
#Read the base file into a raw text variable
base_file = open(os.getcwd()+ "/spam.txt", 'rt')
raw_text = base_file.read()
base_file.close()

#Extract tokens
token_list = nltk.word_tokenize(raw_text)
print("Token List : ", token_list[:20])
print("\n Total Tokens : ", len(token_list))
# Out:
# Token List :  ['text', 'Free', 'entry', 'in', '2', 'a', 'wkly', 'comp', 'to', 'win', 'FA', 'Cup', 'final', 'tkts', '21st', 'May', '2005', '.', 'Text', 'FA']
#
#  Total Tokens :  21301

# %% [markdown]
# <h3>Removing Punctuation</h3>

# %%
#Use the punkt library to extracr tokens
token_list2 = list(filter(lambda token: nltk.tokenize.punkt.PunktToken(token).is_non_punct, token_list))
print("Token List after removing the punctuation: ", token_list2[:20])
print("\n Total Tokens after removing the punctuation : ", len(token_list2))
# Out:
# Token List after removing the punctuation:  ['text', 'Free', 'entry', 'in', '2', 'a', 'wkly', 'comp', 'to', 'win', 'FA', 'Cup', 'final', 'tkts', '21st', 'May', '2005', 'Text', 'FA', 'to']
#
#  Total Tokens after removing the punctuation :  17595

# %% [markdown]
# <h3>Remove Stopwords</h3>

# %%
#Download the standard stopword list
#nltk.download('stopwords')
from nltk.corpus import stopwords

#Remove stopwords
corpus = list(filter(lambda token: token not in stopwords.words('english'), token_list2))
print("Token list after stopword removal: ", corpus[:20])
print("\nTotal tokens after stopword removal : ", len(corpus))
# Out:
# Token list after stopword removal:  ['text', 'Free', 'entry', '2', 'wkly', 'comp', 'win', 'FA', 'Cup', 'final', 'tkts', '21st', 'May', '2005', 'Text', 'FA', '87121', 'receive', 'entry', 'question']
#
# Total tokens after stopword removal :  13356

# %% [markdown]
# <h3>Final Word Count</h3>

# %%
from collections import Counter
freq = Counter(corpus).most_common(250)
print(freq)
# Out:
# [('call', 187), ('2', 176), ('Call', 138), ('FREE', 113), ('ur', 107), ('4', 97), ('mobile', 95), ('U', 90), ('You', 82), ('claim', 78), ('Txt', 75), ('text', 74), ('To', 74), ('prize', 73), ('txt', 71), ('Your', 71), ('T', 66), ("'s", 65), ('STOP', 63), ('free', 62), ('reply', 58), ('contact', 56), ('u', 55), ('week', 52), ('service', 49), ('send', 47), ('Nokia', 46), ('C', 45), ('get', 45), ('NOW', 45), ('Reply', 44), ('per', 44), ('stop', 44), ('cash', 43), ('Free', 42), ('I', 42), ('new', 42), ('URGENT', 41), ('This', 41), ('Cs', 41), ('Text', 40), ('customer', 39), ('No', 38), ('We', 37), ('awarded', 37), ('1', 36), ('Please', 35), ('Get', 34), ('draw', 34), ('line', 33), ('phone', 33), ('Claim', 32), ('150ppm', 32), ('every', 32), ('PO', 31), ('shows', 31), ('Just', 31), ('receive', 30), ('win', 28), ('Mobile', 28), ('number', 28), ('apply', 27), ('3', 26), ('latest', 26), ('message', 26), ('guaranteed', 26), ('16', 26), ('award', 26), ('150p', 26), ('tone', 26), ('1st', 26), ('YOU', 26), ('collection', 26), ('entry', 25), ('word', 25), ('selected', 25), ('know', 25), ('mins', 25), ('landline', 25), ('The', 24), ('For', 24), ('18', 24), ('WON', 23), ('Box', 23), ('GUARANTEED', 23), ('500', 23), ('Orange', 23), ('network', 22), ('UR', 22), ('Send', 22), ('weekly', 22), ('attempt', 22), ('back', 21), ('Holiday', 21), ('SAE', 21), ('CALL', 21), ('8007', 21), ('Valid', 20), ('UK', 20), ('msg', 20), ('2nd', 20), ('rate', 19), ('camera', 19), ('Prize', 19), ('live', 19), ('chat', 19), ('86688', 19), ('WIN', 19), ('chance', 19), ('await', 19), ('time', 19), ('http', 18), ('SMS', 18), ('ringtone', 18), ('please', 18), ('mob', 18), ('find', 18), ('750', 18), ('land', 18), ('video', 18), ('A', 18), ('pounds', 17), ('tried', 17), ('Urgent', 17), ('Code', 17), ('12hrs', 17), ('Expires', 17), ('collect', 17), ('vouchers', 17), ('want', 17), ('tones', 17), ('100', 16), ('08000930705', 16), ('Bonus', 16), ('PRIVATE', 16), ('Account', 16), ('Statement', 16), ('Identifier', 16), ('Todays', 16), ("n't", 16), ('Now', 16), ('go', 16), ('dating', 16), ('Dear', 16), ('texts', 16), ('Hi', 16), ('Had', 15), ('colour', 15), ('Cost', 15), ('YES', 15), ('delivery', 15), ('New', 15), ('waiting', 15), ('trying', 15), ('operator', 15), ('Ur', 15), ('NOKIA', 15), ('unsubscribe', 15), ('Offer', 15), ('MobileUpd8', 15), ('08000839402', 15), ('Do', 15), ('CASH', 14), ('info', 14), ('next', 14), ('If', 14), ('sexy', 14), ('today', 14), ('10p', 14), ('Congratulations', 14), ('wk', 14), ('gift', 14), ('CHAT', 14), ('Only', 14), ('min', 14), ('like', 13), ('Thanks', 13), ('0800', 13), ('Win', 13), ('Ltd', 13), ('87066', 13), ('easy', 13), ('take', 13), ('Double', 13), ('SavaMob', 13), ('offers', 13), ('2003', 13), ('800', 13), ('points', 13), ('TONE', 13), ('tell', 13), ('mates', 13), ('As', 12), ('code', 12), ('Update', 12), ('charged', 12), ('complimentary', 12), ('winner', 12), ('top', 12), ('Want', 12), ('services', 12), ('anytime', 12), ('phones', 12), ('worth', 12), ('un-redeemed', 12), ('NEW', 12), ('r', 12), ('final', 11), ('FreeMsg', 11), ('valued', 11), ('From', 11), ('eg', 11), ('play', 11), ('holiday', 11), ('GO', 11), ('yr', 11), ('Stop', 11), ('friend', 11), ('order', 11), ('content', 11), ('make', 11), ('offer', 11), ('Motorola', 11), ('price', 11), ('days', 11), ('games', 11), ('wkly', 10), ('comp', 10), ('R', 10), ('Congrats', 10), ('representative', 10), ('Caller', 10), ('Quiz', 10), ('player', 10), ('sent', 10), ('Customer', 10), ('See', 10), ('thinks', 10), ('MUSIC', 10), ('Video', 10), ('charge', 10), ('HMV', 10), ('150p/msg', 10), ('currently', 10), ('Latest', 10), ('txts', 10), ('TXT', 10), ('Chat', 10), ('opt', 10), ('POBox', 10)]
